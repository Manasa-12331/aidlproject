# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import necessary libraries.

# %%
import os
import zipfile
import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter
from PIL import Image
import seaborn as sns
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import shutil

# %% [markdown]
# Unzip the dataset stored in your Google Drive.

# %%
# !unzip /content/drive/MyDrive/Projects/archive.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: archive/train/0/9687273L.png
#   inflating: archive/train/0/9689906R.png
#  extracting: archive/train/0/9690910L.png
#  extracting: archive/train/0/9690910R.png
#   inflating: archive/train/0/9691359L.png
#   inflating: archive/train/0/9691359R.png
#   inflating: archive/train/0/9692163L.png
#   inflating: archive/train/0/9692604L.png
#   inflating: archive/train/0/9692604R.png
#   inflating: archive/train/0/9692923R.png
#   inflating: archive/train/0/9693364R.png
#   inflating: archive/train/0/9693599L.png
#   inflating: archive/train/0/9693599R.png
#   inflating: archive/train/0/9694101L.png
#   inflating: archive/train/0/9694101R.png
#   inflating: archive/train/0/9695317L.png
#   inflating: archive/train/0/9695317R.png
#   inflating: archive/train/0/9695621L.png
#   inflating: archive/train/0/9695881L.png
#   inflating: archive/train/0/9695881R.png
#   inflating: archive/train/0/9695948L.png
#   inflating: archive/train/0/9695948R.png
#   inflating: archive/train/0/9696350R.png
#   inflating: archive/train/0/9696897L.png
#   inflating: archive/train/0/9696897R.png
#   inflating: archive/train/0/9697904L.png
#   inflating: archive/train/0/9697904R.png
#   inflating: archive/train/0/9699340L.png
#   inflating: archive/train/0/9699340R.png
#   inflating: archive/train/0/9699399L.png
#   inflating: archive/train/0/9699399R.png
#   inflating: archive/train/0/9700163R.png
#   inflating: archive/train/0/9700908L.png
#   inflating: archive/train/0/9700908R.png
#   inflating: archive/train/0/9701362R.png
#   inflating: archive/train/0/9701645L.png
#   inflating: archive/train/0/9701645R.png
#   inflating: archive/train/0/9702644L.png
#   inflating: archive/train/0/9703327L.png
#   inflating: archive/train/0/9703469L.png
#   inflating: archive/train/0/9703469R.png
#   inflating: archive/train/0/9703829L.png
#   inflating: archive/train/0/9703829R.png
#  extracting: archive/train/0/9703978L.png
#   inflating: archive/train/0/9703978R.png
#   inflating: archive/train/0/9704911L.png
#   inflating: archive/train/0/9704911R.png
#   inflating: archive/train/0/9706842L.png
#   inflating: archive/train/0/9706842R.png
#   inflating: archive/train/0/9706954L.png
#   inflating: archive/train/0/9706954R.png
#   inflating: archive/train/0/9707911L.png
#   inflating: archive/train/0/9707911R.png
#   inflating: archive/train/0/9708416L.png
#   inflating: archive/train/0/9708416R.png
#   inflating: archive/train/0/9709164L.png
#   inflating: archive/train/0/9709164R.png
#   inflating: archive/train/0/9710415L.png
#   inflating: archive/train/0/9710415R.png
#   inflating: archive/train/0/9710976R.png
#   inflating: archive/train/0/9713153R.png
#   inflating: archive/train/0/9714513L.png
#   inflating: archive/train/0/9714958L.png
#   inflating: archive/train/0/9715480L.png
#   inflating: archive/train/0/9715626R.png
#   inflating: archive/train/0/9715892L.png
#   inflating: archive/train/0/9716943L.png
#   inflating: archive/train/0/9717685L.png
#   inflating: archive/train/0/9717685R.png
#   inflating: archive/train/0/9717977L.png
#   inflating: archive/train/0/9717977R.png
#   inflating: archive/train/0/9718167L.png
#   inflating: archive/train/0/9721284R.png
#  extracting: archive/train/0/9723032L.png
#   inflating: archive/train/0/9723032R.png
#   inflating: archive/train/0/9724475L.png
#   inflating: archive/train/0/9724475R.png
#   inflating: archive/train/0/9724907L.png
#   inflating: archive/train/0/9725279L.png
#   inflating: archive/train/0/9725914L.png
#   inflating: archive/train/0/9725914R.png
#   inflating: archive/train/0/9727418R.png
#   inflating: archive/train/0/9728026R.png
#   inflating: archive/train/0/9728546R.png
#   inflating: archive/train/0/9728920R.png
#   inflating: archive/train/0/9729215L.png
#   inflating: archive/train/0/9729215R.png
#   inflating: archive/train/0/9729553L.png
#   inflating: archive/train/0/9729553R.png
#   inflating: archive/train/0/9730028L.png
#   inflating: archive/train/0/9730028R.png
#   inflating: archive/train/0/9730488L.png
#   inflating: archive/train/0/9732234L.png
#   inflating: archive/train/0/9732234R.png
#   inflating: archive/train/0/9732727L.png
#   inflating: archive/train/0/9734179L.png
#   inflating: archive/train/0/9735805R.png
#   inflating: archive/train/0/9737043L.png
#   inflating: archive/train/0/9737043R.png
#   inflating: archive/train/0/9737302L.png
#  extracting: archive/train/0/9738052L.png
#   inflating: archive/train/0/9738052R.png
#   inflating: archive/train/0/9739273L.png
#   inflating: archive/train/0/9740738L.png
#   inflating: archive/train/0/9740738R.png
#   inflating: archive/train/0/9741448L.png
#   inflating: archive/train/0/9742563R.png
#   inflating: archive/train/0/9742871L.png
#   inflating: archive/train/0/9743577L.png
#   inflating: archive/train/0/9744568L.png
#   inflating: archive/train/0/9744568R.png
#   inflating: archive/train/0/9745242L.png
#   inflating: archive/train/0/9745242R.png
#   inflating: archive/train/0/9745368L.png
#   inflating: archive/train/0/9746416L.png
#   inflating: archive/train/0/9746585L.png
#   inflating: archive/train/0/9746894L.png
#   inflating: archive/train/0/9747255L.png
#   inflating: archive/train/0/9747255R.png
#   inflating: archive/train/0/9747379L.png
#   inflating: archive/train/0/9747379R.png
#  extracting: archive/train/0/9747589L.png
#   inflating: archive/train/0/9747589R.png
#   inflating: archive/train/0/9748081L.png
#   inflating: archive/train/0/9748081R.png
#   inflating: archive/train/0/9748094L.png
#   inflating: archive/train/0/9748587R.png
#   inflating: archive/train/0/9751625L.png
#   inflating: archive/train/0/9752000L.png
#   inflating: archive/train/0/9752000R.png
#   inflating: archive/train/0/9753414R.png
#   inflating: archive/train/0/9753871L.png
#   inflating: archive/train/0/9753871R.png
#   inflating: archive/train/0/9754338L.png
#   inflating: archive/train/0/9754338R.png
#   inflating: archive/train/0/9754894L.png
#   inflating: archive/train/0/9754894R.png
#   inflating: archive/train/0/9754907L.png
#   inflating: archive/train/0/9754907R.png
#   inflating: archive/train/0/9755372L.png
#   inflating: archive/train/0/9755372R.png
#   inflating: archive/train/0/9756932L.png
#   inflating: archive/train/0/9757487L.png
#   inflating: archive/train/0/9757487R.png
#   inflating: archive/train/0/9759382L.png
#   inflating: archive/train/0/9759382R.png
#   inflating: archive/train/0/9759454L.png
#   inflating: archive/train/0/9759454R.png
#   inflating: archive/train/0/9759956L.png
#   inflating: archive/train/0/9761200L.png
#   inflating: archive/train/0/9761200R.png
#   inflating: archive/train/0/9762412L.png
#   inflating: archive/train/0/9762412R.png
#   inflating: archive/train/0/9762677R.png
#   inflating: archive/train/0/9762713L.png
#   inflating: archive/train/0/9762713R.png
#   inflating: archive/train/0/9763898L.png
#   inflating: archive/train/0/9763898R.png
#   inflating: archive/train/0/9764454R.png
#  extracting: archive/train/0/9764947R.png
#   inflating: archive/train/0/9765419L.png
#   inflating: archive/train/0/9765419R.png
#   inflating: archive/train/0/9765432L.png
#   inflating: archive/train/0/9766449L.png
#   inflating: archive/train/0/9766449R.png
#   inflating: archive/train/0/9767651L.png
#   inflating: archive/train/0/9767651R.png
#   inflating: archive/train/0/9767980R.png
#   inflating: archive/train/0/9768869R.png
#   inflating: archive/train/0/9770003L.png
#   inflating: archive/train/0/9770003R.png
#   inflating: archive/train/0/9770617L.png
#   inflating: archive/train/0/9770617R.png
#   inflating: archive/train/0/9771115L.png
#   inflating: archive/train/0/9771115R.png
#   inflating: archive/train/0/9771214R.png
#   inflating: archive/train/0/9771624L.png
#   inflating: archive/train/0/9771624R.png
#   inflating: archive/train/0/9773633L.png
#   inflating: archive/train/0/9773633R.png
#   inflating: archive/train/0/9775475L.png
#   inflating: archive/train/0/9775475R.png
#   inflating: archive/train/0/9776525R.png
#   inflating: archive/train/0/9776644L.png
#   inflating: archive/train/0/9777014L.png
#   inflating: archive/train/0/9780165L.png
#   inflating: archive/train/0/9780165R.png
#   inflating: archive/train/0/9781279L.png
#   inflating: archive/train/0/9781555L.png
#   inflating: archive/train/0/9781555R.png
#   inflating: archive/train/0/9782690L.png
#   inflating: archive/train/0/9782690R.png
#   inflating: archive/train/0/9785604R.png
#   inflating: archive/train/0/9785684R.png
#   inflating: archive/train/0/9785978R.png
#   inflating: archive/train/0/9786191R.png
#   inflating: archive/train/0/9787204R.png
#   inflating: archive/train/0/9787305L.png
#   inflating: archive/train/0/9787305R.png
#   inflating: archive/train/0/9787576L.png
#   inflating: archive/train/0/9787693L.png
#   inflating: archive/train/0/9788503L.png
#   inflating: archive/train/0/9788503R.png
#   inflating: archive/train/0/9788608L.png
#   inflating: archive/train/0/9788979L.png
#   inflating: archive/train/0/9788979R.png
#   inflating: archive/train/0/9789297L.png
#   inflating: archive/train/0/9789297R.png
#   inflating: archive/train/0/9789504L.png
#   inflating: archive/train/0/9789504R.png
#   inflating: archive/train/0/9789712L.png
#   inflating: archive/train/0/9789767L.png
#   inflating: archive/train/0/9789767R.png
#   inflating: archive/train/0/9790287L.png
#   inflating: archive/train/0/9790287R.png
#   inflating: archive/train/0/9791525L.png
#   inflating: archive/train/0/9791525R.png
#   inflating: archive/train/0/9794140L.png
#   inflating: archive/train/0/9794140R.png
#   inflating: archive/train/0/9794269L.png
#   inflating: archive/train/0/9794269R.png
#   inflating: archive/train/0/9794849L.png
#   inflating: archive/train/0/9794849R.png
#   inflating: archive/train/0/9795183L.png
#   inflating: archive/train/0/9795183R.png
#   inflating: archive/train/0/9795559L.png
#   inflating: archive/train/0/9797352R.png
#   inflating: archive/train/0/9798131L.png
#   inflating: archive/train/0/9798131R.png
#   inflating: archive/train/0/9798351R.png
#   inflating: archive/train/0/9798668L.png
#   inflating: archive/train/0/9798668R.png
#   inflating: archive/train/0/9800154L.png
#   inflating: archive/train/0/9800154R.png
#   inflating: archive/train/0/9800893L.png
#   inflating: archive/train/0/9800893R.png
#   inflating: archive/train/0/9801130L.png
#   inflating: archive/train/0/9801130R.png
#   inflating: archive/train/0/9802372L.png
#   inflating: archive/train/0/9802372R.png
#   inflating: archive/train/0/9802822L.png
#   inflating: archive/train/0/9802822R.png
#   inflating: archive/train/0/9803621L.png
#   inflating: archive/train/0/9803621R.png
#   inflating: archive/train/0/9805234L.png
#   inflating: archive/train/0/9805234R.png
#   inflating: archive/train/0/9805321L.png
#   inflating: archive/train/0/9805321R.png
#   inflating: archive/train/0/9805639L.png
#   inflating: archive/train/0/9805639R.png
#   inflating: archive/train/0/9806950L.png
#   inflating: archive/train/0/9806950R.png
#   inflating: archive/train/0/9808689L.png
#   inflating: archive/train/0/9808689R.png
#   inflating: archive/train/0/9809342L.png
#   inflating: archive/train/0/9809342R.png
#   inflating: archive/train/0/9811200L.png
#   inflating: archive/train/0/9811940L.png
#   inflating: archive/train/0/9812166L.png
#   inflating: archive/train/0/9812166R.png
#   inflating: archive/train/0/9812739L.png
#   inflating: archive/train/0/9812739R.png
#   inflating: archive/train/0/9813353L.png
#   inflating: archive/train/0/9813353R.png
#   inflating: archive/train/0/9813851L.png
#   inflating: archive/train/0/9813851R.png
#   inflating: archive/train/0/9815467L.png
#   inflating: archive/train/0/9815467R.png
#   inflating: archive/train/0/9815779L.png
#   inflating: archive/train/0/9815779R.png
#   inflating: archive/train/0/9816138R.png
#   inflating: archive/train/0/9816968L.png
#   inflating: archive/train/0/9817141L.png
#   inflating: archive/train/0/9817141R.png
#   inflating: archive/train/0/9817618L.png
#   inflating: archive/train/0/9817618R.png
#   inflating: archive/train/0/9819149L.png
#   inflating: archive/train/0/9819149R.png
#   inflating: archive/train/0/9820271L.png
#   inflating: archive/train/0/9821982L.png
#   inflating: archive/train/0/9824703R.png
#   inflating: archive/train/0/9825282L.png
#   inflating: archive/train/0/9825282R.png
#   inflating: archive/train/0/9825783R.png
#   inflating: archive/train/0/9828044L.png
#   inflating: archive/train/0/9828044R.png
#   inflating: archive/train/0/9828518R.png
#   inflating: archive/train/0/9829221L.png
#   inflating: archive/train/0/9829221R.png
#   inflating: archive/train/0/9830316L.png
#   inflating: archive/train/0/9832457L.png
#   inflating: archive/train/0/9832457R.png
#   inflating: archive/train/0/9833489R.png
#   inflating: archive/train/0/9833782R.png
#   inflating: archive/train/0/9833809R.png
#   inflating: archive/train/0/9833835L.png
#   inflating: archive/train/0/9833835R.png
#   inflating: archive/train/0/9834533L.png
#   inflating: archive/train/0/9834533R.png
#   inflating: archive/train/0/9834806L.png
#   inflating: archive/train/0/9834806R.png
#   inflating: archive/train/0/9835291L.png
#   inflating: archive/train/0/9835291R.png
#   inflating: archive/train/0/9836062L.png
#   inflating: archive/train/0/9836062R.png
#   inflating: archive/train/0/9836330L.png
#   inflating: archive/train/0/9836547L.png
#   inflating: archive/train/0/9836547R.png
#   inflating: archive/train/0/9836553L.png
#   inflating: archive/train/0/9836553R.png
#   inflating: archive/train/0/9836853L.png
#   inflating: archive/train/0/9837054L.png
#   inflating: archive/train/0/9837054R.png
#   inflating: archive/train/0/9837324L.png
#   inflating: archive/train/0/9837324R.png
#   inflating: archive/train/0/9837774L.png
#   inflating: archive/train/0/9837774R.png
#   inflating: archive/train/0/9837987L.png
#   inflating: archive/train/0/9841058L.png
#   inflating: archive/train/0/9841058R.png
#   inflating: archive/train/0/9841269L.png
#   inflating: archive/train/0/9841269R.png
#   inflating: archive/train/0/9841364L.png
#   inflating: archive/train/0/9841364R.png
#   inflating: archive/train/0/9841815L.png
#   inflating: archive/train/0/9841838L.png
#   inflating: archive/train/0/9843822L.png
#   inflating: archive/train/0/9844581L.png
#   inflating: archive/train/0/9846783L.png
#   inflating: archive/train/0/9846783R.png
#   inflating: archive/train/0/9846846L.png
#   inflating: archive/train/0/9847480L.png
#   inflating: archive/train/0/9847480R.png
#   inflating: archive/train/0/9848263L.png
#   inflating: archive/train/0/9849852L.png
#   inflating: archive/train/0/9850237L.png
#   inflating: archive/train/0/9850237R.png
#   inflating: archive/train/0/9850845L.png
#   inflating: archive/train/0/9850845R.png
#   inflating: archive/train/0/9851631L.png
#   inflating: archive/train/0/9851631R.png
#   inflating: archive/train/0/9853065L.png
#   inflating: archive/train/0/9853065R.png
#   inflating: archive/train/0/9853267L.png
#   inflating: archive/train/0/9853267R.png
#   inflating: archive/train/0/9853562L.png
#   inflating: archive/train/0/9854226L.png
#   inflating: archive/train/0/9854226R.png
#   inflating: archive/train/0/9854269L.png
#   inflating: archive/train/0/9854269R.png
#   inflating: archive/train/0/9854620L.png
#   inflating: archive/train/0/9854620R.png
#   inflating: archive/train/0/9854837L.png
#   inflating: archive/train/0/9854837R.png
#   inflating: archive/train/0/9855059R.png
#   inflating: archive/train/0/9855117R.png
#   inflating: archive/train/0/9855149R.png
#   inflating: archive/train/0/9856561R.png
#   inflating: archive/train/0/9856744L.png
#   inflating: archive/train/0/9856744R.png
#   inflating: archive/train/0/9857351L.png
#   inflating: archive/train/0/9857351R.png
#   inflating: archive/train/0/9860637L.png
#   inflating: archive/train/0/9860739L.png
#   inflating: archive/train/0/9860739R.png
#   inflating: archive/train/0/9861303L.png
#   inflating: archive/train/0/9861560L.png
#   inflating: archive/train/0/9861560R.png
#   inflating: archive/train/0/9861699R.png
#  extracting: archive/train/0/9862541L.png
#   inflating: archive/train/0/9862541R.png
#   inflating: archive/train/0/9862725L.png
#   inflating: archive/train/0/9862725R.png
#   inflating: archive/train/0/9862741L.png
#   inflating: archive/train/0/9862741R.png
#   inflating: archive/train/0/9862772L.png
#   inflating: archive/train/0/9862772R.png
#   inflating: archive/train/0/9863321L.png
#   inflating: archive/train/0/9863321R.png
#   inflating: archive/train/0/9863737L.png
#   inflating: archive/train/0/9864266L.png
#   inflating: archive/train/0/9865771L.png
#   inflating: archive/train/0/9865771R.png
#   inflating: archive/train/0/9866291R.png
#   inflating: archive/train/0/9866764L.png
#   inflating: archive/train/0/9866764R.png
#   inflating: archive/train/0/9867611L.png
#   inflating: archive/train/0/9867611R.png
#   inflating: archive/train/0/9867760R.png
#   inflating: archive/train/0/9868006L.png
#   inflating: archive/train/0/9868006R.png
#   inflating: archive/train/0/9869252L.png
#   inflating: archive/train/0/9869252R.png
#   inflating: archive/train/0/9871097L.png
#   inflating: archive/train/0/9871097R.png
#   inflating: archive/train/0/9871786L.png
#   inflating: archive/train/0/9871786R.png
#   inflating: archive/train/0/9872535L.png
#   inflating: archive/train/0/9872535R.png
#   inflating: archive/train/0/9872789L.png
#   inflating: archive/train/0/9872789R.png
#   inflating: archive/train/0/9872828R.png
#   inflating: archive/train/0/9873057L.png
#   inflating: archive/train/0/9873057R.png
#   inflating: archive/train/0/9873103L.png
#   inflating: archive/train/0/9873103R.png
#   inflating: archive/train/0/9874784L.png
#   inflating: archive/train/0/9875794R.png
#   inflating: archive/train/0/9876530L.png
#   inflating: archive/train/0/9876530R.png
#   inflating: archive/train/0/9876792L.png
#   inflating: archive/train/0/9876792R.png
#   inflating: archive/train/0/9877295L.png
#   inflating: archive/train/0/9877295R.png
#   inflating: archive/train/0/9878114L.png
#   inflating: archive/train/0/9878114R.png
#   inflating: archive/train/0/9878614L.png
#   inflating: archive/train/0/9878614R.png
#   inflating: archive/train/0/9878765L.png
#   inflating: archive/train/0/9878765R.png
#   inflating: archive/train/0/9878786L.png
#   inflating: archive/train/0/9878786R.png
#   inflating: archive/train/0/9879069L.png
#   inflating: archive/train/0/9879069R.png
#   inflating: archive/train/0/9880782L.png
#   inflating: archive/train/0/9880782R.png
#   inflating: archive/train/0/9881756L.png
#   inflating: archive/train/0/9881756R.png
#   inflating: archive/train/0/9882788L.png
#   inflating: archive/train/0/9884710L.png
#   inflating: archive/train/0/9884710R.png
#   inflating: archive/train/0/9885303R.png
#   inflating: archive/train/0/9886696R.png
#   inflating: archive/train/0/9888515L.png
#   inflating: archive/train/0/9888561L.png
#   inflating: archive/train/0/9888561R.png
#   inflating: archive/train/0/9888600L.png
#   inflating: archive/train/0/9888600R.png
#   inflating: archive/train/0/9889523L.png
#   inflating: archive/train/0/9889793L.png
#   inflating: archive/train/0/9889793R.png
#   inflating: archive/train/0/9890264L.png
#   inflating: archive/train/0/9890414L.png
#   inflating: archive/train/0/9890414R.png
#   inflating: archive/train/0/9891264R.png
#   inflating: archive/train/0/9891421L.png
#   inflating: archive/train/0/9891421R.png
#   inflating: archive/train/0/9892241L.png
#   inflating: archive/train/0/9892241R.png
#   inflating: archive/train/0/9892270L.png
#   inflating: archive/train/0/9892736L.png
#   inflating: archive/train/0/9892736R.png
#   inflating: archive/train/0/9893482R.png
#   inflating: archive/train/0/9893793L.png
#   inflating: archive/train/0/9893793R.png
#   inflating: archive/train/0/9894048L.png
#   inflating: archive/train/0/9894048R.png
#   inflating: archive/train/0/9894184R.png
#   inflating: archive/val/4/9824005L.png
#  extracting: archive/val/4/9928082L.png
#   inflating: archive/val/4/9961951L.png
#   inflating: archive/val/4/9971710L.png
#  extracting: archive/val/4/9997856L.png

# %% [markdown]
# Define paths for training, testing, and validation datasets.
#
# list_of_classes contains the class labels for the dataset.

# %%
train_path = '/content/archive/train'
test_path = '/content/archive/test'
valid_path = '/content/archive/val'
list_of_classes=['Healthy', 'Doubtful', 'Minimal', 'Moderate', 'Severe']

# %% [markdown]
# We have three datasets for training,testing and validation. Finding length of each dataset.Organizing the file paths and labels into DataFrames, enabling efficient data loading and preprocessing for training and evaluation.

# %%
 for d in [train_path, test_path, valid_path]:
    filepaths = []
    labels=[]
    classlist=os.listdir(d)
    for klass in classlist:
        intklass=int(klass)
        label=list_of_classes[intklass]
        classpath=os.path.join(d, klass)
        flist=os.listdir(classpath)
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(label)
    Fseries=pd.Series(filepaths, name='filepaths')
    Lseries=pd.Series(labels, name='labels')
    pdf=pd.concat([Fseries, Lseries], axis=1)
    if d == test_path:
        test_df=pdf
    elif d == valid_path:
        valid_df=pdf
    else:
        train_df=pdf
print('train_df lenght: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# get the number of classes and the images count for each class in train_df
classes=sorted(list(train_df['labels'].unique()))
class_count = len(classes)
print('The number of classes in the dataset is: ', class_count)
groups=train_df.groupby('labels')
print('{0:^30s} {1:^13s}'.format('CLASS', 'IMAGE COUNT'))
countlist=[]
classlist=[]
for label in sorted(list(train_df['labels'].unique())):
    group=groups.get_group(label)
    countlist.append(len(group))
    classlist.append(label)
    print('{0:^30s} {1:^13s}'.format(label, str(len(group))))



# Visualization for dataset splits
plt.figure(figsize=(8, 6))
split_labels = ['Train', 'Test', 'Validation']
split_counts = [len(train_df), len(test_df), len(valid_df)]
plt.bar(split_labels, split_counts, color=['blue', 'orange', 'green'])
plt.title('Number of Images in Each Dataset Split')
plt.ylabel('Count')
for i, count in enumerate(split_counts):
    plt.text(i, count, str(count), ha='center', va='bottom')
plt.show()


# get the classes with the minimum and maximum number of train images
max_value=np.max(countlist)
max_index=countlist.index(max_value)
max_class=classlist[max_index]
min_value=np.min(countlist)
min_index=countlist.index(min_value)
min_class=classlist[min_index]
print(max_class, ' has the most images= ',max_value, ' ', min_class, ' has the least images= ', min_value)

# Visualization for class distribution in training set
plt.figure(figsize=(10, 8))
plt.barh(classlist, countlist)
plt.title('Number of Images per Class in Training Set')
plt.xlabel('Number of Images')
plt.ylabel('Class')
for i, count in enumerate(countlist):
    plt.text(count, i, str(count), va='center')
plt.tight_layout()
plt.show()

# lets get the average height and width of a sample of the train images
ht=0
wt=0
# select 100 random samples of train_df
train_df_sample=train_df.sample(n=100, random_state=123,axis=0)
for i in range (len(train_df_sample)):
    fpath=train_df_sample['filepaths'].iloc[i]
    img=plt.imread(fpath)
    shape=img.shape
    ht += shape[0]
    wt += shape[1]
print('average height= ', ht//100, ' average width= ', wt//100, 'aspect ratio= ', ht/wt)
# Out:
# train_df lenght:  5778   test_df length:  1656   valid_df length:  826
# The number of classes in the dataset is:  5
#             CLASS               IMAGE COUNT
#            Doubtful                1046
#            Healthy                 2286
#            Minimal                 1516
#            Moderate                 757
#             Severe                  173
# Healthy  has the most images=  2286   Severe  has the least images=  173
# average height=  224  average width=  224 aspect ratio=  1.0

# %% [markdown]
# The first visualisation show the distribution of images in each dataset split.
# The second visualisation shows the distribution of images per class in training dataset.

# %% [markdown]
# It is found that training, testing, and validation sets, have 5778, 1656, and 826 images respectively.
#
# The dataset is imbalanced, with the Healthy class having the most images (2286) and the Severe class having the fewest (173), which may bias the model toward the majority class.
#
#  The images have an average height and width of 224pixels with an aspect ratio of 1.0, indicating they are square and suitable for deep learning models requiring fixed input sizes.

# %% [markdown]
# As we found that the dataset is imbalanced we are reducing it by limiting the number of samples per class to a specified maximum (max_samples) while ensuring no class falls below a minimum threshold (min_samples).
#
# By setting max_samples=500, the function ensures no class exceeds 500 samples, addressing class imbalance and preventing overrepresentation of majority classes like Healthy.
#
# With min_samples=173, the function retains all samples for minority classes (e.g., Severe), ensuring they are not underrepresented in the trimmed dataset.
#
# We are using random sampling (random_state=123) to maintain fairness and reproducibility when reducing class sizes.
#
# Overall, this step of trimming helps create a more balanced dataset, reducing bias and improving the model's ability to generalize across all classes.

# %%
def trim(df, max_samples, min_samples, column):
    df=df.copy()
    groups=df.groupby(column)
    trimmed_df = pd.DataFrame(columns = df.columns)
    groups=df.groupby(column)
    for label in df[column].unique():
        group=groups.get_group(label)
        count=len(group)
        if count > max_samples:
            sampled_group=group.sample(n=max_samples, random_state=123,axis=0)
            trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
        else:
            if count>=min_samples:
                sampled_group=group
                trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
    print('after trimming, the maximum samples in any class is now ',max_samples, ' and the minimum samples in any class is ', min_samples)
    return trimmed_df

max_samples=500 # since each class has more than 200 images all classes will be trimmed to have 200 images per class
min_samples=173
column='labels'
train_df= trim(train_df, max_samples, min_samples, column)
# Out:
# after trimming, the maximum samples in any class is now  500  and the minimum samples in any class is  173

# %% [markdown]
# **Data Augmentation:** The balance function uses techniques like horizontal flipping, rotation, and zooming to generate synthetic images, increasing dataset diversity and addressing class imbalance.
#
# **Target Class Size:** By setting n=500, the function ensures each class reaches 500 samples, boosting minority classes (e.g., Severe) to match the target size.
#
# **Augmentation Process:** For classes with fewer than 500 samples, the function creates additional images (delta = n - sample_count) and saves them in a dedicated directory (aug_dir).
#
# **Dataset Expansion:** The function merges the original dataset with the augmented images, increasing the total dataset size from 2173 to 2500 samples.
#
# **Improved Model Generalization:** Augmentation enhances the dataset's variability, helping the model generalize better and reducing overfitting to minority or majority classes.

# %%
def balance(df, n, working_dir, img_size):
    df=df.copy()
    print('Initial length of dataframe is ', len(df))
    aug_dir=os.path.join(working_dir, 'aug')# directory to store augmented images
    if os.path.isdir(aug_dir):# start with an empty directory
        shutil.rmtree(aug_dir)
    os.mkdir(aug_dir)
    for label in df['labels'].unique():
        dir_path=os.path.join(aug_dir,label)
        os.mkdir(dir_path) # make class directories within aug directory
    # create and store the augmented images
    total=0
    gen=ImageDataGenerator(horizontal_flip=True,  rotation_range=20, width_shift_range=.2,height_shift_range=.2, zoom_range=.2)
    groups=df.groupby('labels') # group by class
    for label in df['labels'].unique():  # for every class
        group=groups.get_group(label)  # a dataframe holding only rows with the specified label
        sample_count=len(group)   # determine how many samples there are in this class
        if sample_count< n: # if the class has less than target number of images
            aug_img_count=0
            delta=n - sample_count  # number of augmented images to create
            target_dir=os.path.join(aug_dir, label)  # define where to write the images
            msg='{0:40s} for class {1:^30s} creating {2:^5s} augmented images'.format(' ', label, str(delta))
            print(msg, '\r', end='') # prints over on the same line
            aug_gen=gen.flow_from_dataframe( group,  x_col='filepaths', y_col=None, target_size=img_size,
                                            class_mode=None, batch_size=1, shuffle=False,
                                            save_to_dir=target_dir, save_prefix='aug-', color_mode='rgb',
                                            save_format='jpg')
            while aug_img_count<delta:
                images=next(aug_gen)
                aug_img_count += len(images)
            total +=aug_img_count
    print('Total Augmented images created= ', total)
    # create aug_df and merge with train_df to create composite training set ndf
    aug_fpaths=[]
    aug_labels=[]
    classlist=os.listdir(aug_dir)
    for klass in classlist:
        classpath=os.path.join(aug_dir, klass)
        flist=os.listdir(classpath)
        for f in flist:
          fpath=os.path.join(classpath,f)
          aug_fpaths.append(fpath)
          aug_labels.append(klass)
    Fseries=pd.Series(aug_fpaths, name='filepaths')
    Lseries=pd.Series(aug_labels, name='labels')
    aug_df=pd.concat([Fseries, Lseries], axis=1)
    df=pd.concat([df,aug_df], axis=0).reset_index(drop=True)
    print('Length of augmented dataframe is now ', len(df))
    return df

n=500 # number of samples in each class
working_dir=r'./' # directory to store augmented images
img_size=(224,224) # size of augmented images
train_df=balance(train_df, n, working_dir, img_size)
# Out:
# Initial length of dataframe is  2173
# Found 173 validated image filenames.
# Total Augmented images created=  327
# Length of augmented dataframe is now  2500

# %% [markdown]
# We are combining the classes Healthy, Doubtful, and Minimal into a single class labeled Healthy, simplifying the classification task and reducing complexity.
#
# After relabeling, the dataset now has three classes: Healthy (1500 samples), Moderate (500 samples), and Severe (500 samples), balancing the dataset for better model training.
#
# Hence, Consolidating classes reduces the number of target categories, making the model easier to train and improving its ability to distinguish between the remaining classes.

# %%
def relabel(label_in):
    if label_in =='Healthy' or label_in == 'Doubtful' or label_in =='Minimal':
        label='Healthy'
    else:
        label=label_in
    return label


for df in [train_df, test_df, valid_df]:
    for i in range (len(df)):
        label=df['labels'].iloc[i]
        new_label=relabel(label)
        df['labels'].iloc[i]=new_label
print (train_df['labels'].value_counts())
# Out:
# <ipython-input-8-7d682229a53b>:13: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['labels'].iloc[i]=new_label
# labels
# Healthy     1500
# Severe       500
# Moderate     500
# Name: count, dtype: int64

# %% [markdown]
# We ensure that each class in the dataset has exactly 500 samples, creating a balanced dataset for training and reducing bias toward any particular class.
#
# By setting both max_samples and min_samples to 500, the function guarantees uniformity across all classes, improving the model's ability to generalize and perform equally well on all categories.

# %%
max_samples=500 # since each class has more than 200 images all classes will be trimmed to have 200 images per class
min_samples=500
column='labels'
train_df= trim(train_df, max_samples, min_samples, column)

# Get class counts after trimming
class_counts = train_df['labels'].value_counts()

plt.figure(figsize=(8, 5))
bars = plt.bar(class_counts.index, class_counts.values, color='skyblue')
plt.title('Class Distribution After Trimming', fontsize=14, pad=20)
plt.xlabel('Class Labels', fontsize=12)
plt.ylabel('Number of Images', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# after trimming, the maximum samples in any class is now  500  and the minimum samples in any class is  500

# %% [markdown]
# Finding the number of validated images in each datset(training, testing and validation). We should use only the validated images from training and validation datasets.
# The visualisation shows that all the classes have same number of images after trimming.

# %%
batch_size=20
trgen=ImageDataGenerator(horizontal_flip=True,rotation_range=20 )
t_and_v_gen=ImageDataGenerator()
msg='{0:70s} for train generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
train_gen=trgen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=True, batch_size=batch_size)
msg='{0:70s} for valid generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
valid_gen=t_and_v_gen.flow_from_dataframe(valid_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=batch_size)
# for the test_gen we want to calculate the batch size and test steps such that batch_size X test_steps= number of samples in test set
# this insures that we go through all the sample in the test set exactly once.
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]
test_steps=int(length/test_batch_size)
msg='{0:70s} for test generator'.format(' ')
print(msg, '\r', end='') # prints over on the same line
test_gen=t_and_v_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size,
                                   class_mode='categorical', color_mode='rgb', shuffle=False, batch_size=test_batch_size)
# from the generator we can get information we will need later
classes=list(train_gen.class_indices.keys())
class_indices=list(train_gen.class_indices.values())
class_count=len(classes)
labels=test_gen.labels
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)
# Out:
# Found 1500 validated image filenames belonging to 3 classes.
# Found 826 validated image filenames belonging to 3 classes.
# Found 1656 validated image filenames belonging to 3 classes.
# test batch size:  72   test steps:  23  number of classes :  3

# %% [markdown]
# Display sample batch of images from the data generator, along with their corresponding class labels, to provide a visual understanding of the dataset.

# %%
def show_image_samples(gen ):
    t_dict=gen.class_indices
    classes=list(t_dict.keys())
    images,labels=next(gen) # get a sample batch from the generator
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<5:   #show maximum of 25 images
        r=length
    else:
        r=5
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=images[i] /255
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=14)
        plt.axis('off')
    plt.show()

show_image_samples(train_gen )
show_image_samples(test_gen )
show_image_samples(valid_gen )
